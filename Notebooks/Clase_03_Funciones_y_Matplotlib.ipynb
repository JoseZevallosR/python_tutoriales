# %% [markdown]
# # Clase 3 — Funciones y Gráficos con Matplotlib
#
# *Cómo definir funciones y crear gráficos básicos.*
#
# > Notebook diseñado para Google Colab. Última actualización: 2026-01-31.

# %% [markdown]
# ## 0) Preparación

# %%
import numpy as np
import matplotlib.pyplot as plt
print("Numpy:", np.__version__)
print("Matplotlib:", plt.matplotlib.__version__)

# %% [markdown]
# ## 1) Funciones
# Una función agrupa instrucciones y permite reutilizar código.
#
# Estructura:
# ```python
# def nombre(parametros):
#     ...
#     return resultado
# ```

# %%
def area_circulo(r):
    """Devuelve el área de un círculo de radio r."""
    return np.pi * r**2

print(area_circulo(2))

# %% [markdown]
# ## 2) Matplotlib: gráficos básicos

# %%
x = np.linspace(0, 2*np.pi, 200)
y = np.sin(x)

plt.figure()
plt.plot(x, y)
plt.title("Seno")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()

# %% [markdown]
# ## 3) Ejercicios (completa los TODO)
#
# ### Ejercicio 1
# Implementa `normalize_minmax(values)` que recibe una lista de números y retorna otra lista normalizada a [0, 1].
# Si todos los valores son iguales, retorna una lista de ceros del mismo tamaño.

# %%
def normalize_minmax(values):
    # TODO
    pass

# %% [markdown]
# ### Ejercicio 2
# Implementa `moving_average(values, w)` que calcule el promedio móvil simple.
# - `values`: lista de números
# - `w`: ventana (entero)
# Retorna una lista de longitud `len(values) - w + 1`.

# %%
def moving_average(values, w):
    # TODO
    pass

# %% [markdown]
# ### Ejercicio 3 (gráfico)
# Genera un gráfico con `cos(x)` para x en [0, 2π].
# Guarda el arreglo en `ycos`.

# %%
# TODO
# x = np.linspace(0, 2*np.pi, 200)
# ycos = ...
# plt.figure()
# plt.plot(x, ycos)
# plt.title("Coseno")
# plt.show()

# %% [markdown]
# ## Tests (Clase 3)
# Los tests verifican funciones (lo más importante para autograding).

# %%
# === TESTS CLASE 3 ===
import numpy as np

# normalize_minmax
assert normalize_minmax([0, 5, 10]) == [0.0, 0.5, 1.0]
assert normalize_minmax([3, 3, 3]) == [0.0, 0.0, 0.0]
out = normalize_minmax([-1, 1])
assert np.allclose(out, [0.0, 1.0])

# moving_average
assert np.allclose(moving_average([1, 2, 3, 4], 2), [1.5, 2.5, 3.5])
assert np.allclose(moving_average([1, 2, 3, 4], 4), [2.5])

# ycos existence
try:
    ycos
except NameError:
    raise AssertionError("Debes crear la variable ycos en el Ejercicio 3.")
assert len(ycos) > 0

print("All tests passed ✅")
