# %% [markdown]
# # Clase 2 — Práctica evaluada: Condicionales y Bucles
#
# **Duración sugerida:** 40 minutos
# **Puntaje total:** 100 puntos
#
# ## Indicaciones
# - Resuelve cada ejercicio **en la celda indicada**.
# - **No cambies** los nombres de las variables solicitadas.
# - No necesitas usar librerías externas.
# - Ejecuta al final la celda **“Autoverificación y puntaje”** para revisar tu nota.
#
# ## Distribución del puntaje
# - **Ejercicio 1:** 15 puntos
# - **Ejercicio 2:** 20 puntos
# - **Ejercicio 3:** 20 puntos
# - **Ejercicio 4:** 20 puntos
# - **Ejercicio 5:** 25 puntos

# %% [markdown]
# ## Ejercicio 1 (15 puntos)
# Dado el valor de `numero`, escribe un bloque condicional que:
#
# 1. Guarde en `clasificacion` uno de estos textos: `"positivo"`, `"negativo"` o `"cero"`.
# 2. Guarde en `es_par` el valor `True` o `False` según corresponda.
#
# **Tiempo sugerido:** 5 minutos

# %%
numero = -8

# TODO: escribe tu solución aquí
clasificacion = None
es_par = None

# %% [markdown]
# ## Ejercicio 2 (20 puntos)
# Una tarifa de transporte se calcula así:
#
# - Menor de 5 años: `0.0`
# - De 5 a 17 años: `1.5`
# - Si tiene 60 años o más: `1.2`
# - Si no entra en los casos anteriores y además es estudiante: `2.0`
# - En cualquier otro caso: `2.5`
#
# Usa `if / elif / else` para calcular la variable `tarifa`.
#
# **Tiempo sugerido:** 7 minutos

# %%
edad = 67
es_estudiante = False

# TODO: escribe tu solución aquí
tarifa = None

# %% [markdown]
# ## Ejercicio 3 (20 puntos)
# Usa un bucle `for` para sumar todos los múltiplos de 3 entre 1 y 30, inclusive.
#
# Guarda el resultado en `suma_multiplos_3`.
#
# **Tiempo sugerido:** 7 minutos

# %%
# TODO: escribe tu solución aquí
suma_multiplos_3 = None

# %% [markdown]
# ## Ejercicio 4 (20 puntos)
# Usa un bucle `while` para calcular el factorial de `n`.
#
# Recuerda que:
#
# \[
# n! = n \times (n-1) \times (n-2) \times \dots \times 1
# \]
#
# Guarda el resultado en la variable `factorial`.
#
# **Tiempo sugerido:** 8 minutos

# %%
n = 7

# TODO: escribe tu solución aquí
factorial = None

# %% [markdown]
# ## Ejercicio 5 (25 puntos)
# Dada la lista `temperaturas`, recórrela con un bucle y construye lo siguiente:
#
# 1. `mayores_20`: una lista con los valores mayores que 20.
# 2. `conteo_pares`: cuántos valores de la lista son pares.
# 3. `promedio_mayores_20`: el promedio de los valores mayores que 20.
#
# **Importante:** usa un bucle y condicionales.
# **Tiempo sugerido:** 13 minutos

# %%
temperaturas = [18, 21, 16, 25, 19, 30, 14, 22]

# TODO: escribe tu solución aquí
mayores_20 = None
conteo_pares = None
promedio_mayores_20 = None

# %% [markdown]
# ## Autoverificación y puntaje
# Ejecuta esta celda al final.
# Si tus respuestas están correctas, verás tu puntaje sobre 100.

# %%
puntaje = 0
detalle = []

# Ejercicio 1
try:
    assert clasificacion == "negativo"
    assert es_par is True
    puntaje += 15
    detalle.append("Ejercicio 1: 15/15")
except Exception:
    detalle.append("Ejercicio 1: 0/15")

# Ejercicio 2
try:
    assert tarifa == 1.2
    puntaje += 20
    detalle.append("Ejercicio 2: 20/20")
except Exception:
    detalle.append("Ejercicio 2: 0/20")

# Ejercicio 3
try:
    assert suma_multiplos_3 == 165
    puntaje += 20
    detalle.append("Ejercicio 3: 20/20")
except Exception:
    detalle.append("Ejercicio 3: 0/20")

# Ejercicio 4
try:
    assert factorial == 5040
    puntaje += 20
    detalle.append("Ejercicio 4: 20/20")
except Exception:
    detalle.append("Ejercicio 4: 0/20")

# Ejercicio 5
try:
    assert mayores_20 == [21, 25, 30, 22]
    assert conteo_pares == 5
    assert abs(promedio_mayores_20 - 24.5) < 1e-9
    puntaje += 25
    detalle.append("Ejercicio 5: 25/25")
except Exception:
    detalle.append("Ejercicio 5: 0/25")

print("Resultado de la autoverificación")
print("-" * 35)
for item in detalle:
    print(item)
print("-" * 35)
print(f"Puntaje total: {puntaje}/100")
